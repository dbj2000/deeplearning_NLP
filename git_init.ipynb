# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=False)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pwd
# !ls /content/gdrive/MyDrive/'Colab Notebooks'/deeplearning_NLP  #경로 명 내에 띄어쓰기는 ''로 묶는다
# Out:
# /content/gdrive/My Drive/Colab Notebooks/deeplearning_NLP
#  data
#  git_init.ipynb
# '잠재 디리클레 할당(Latent Dirichlet Allocation, LDA).ipynb'
# '잠재 의미 분석(Latent Semantic Analysis, LSA).ipynb'
#  perfume
# '문서 벡터를 이용한 추천 시스템(Recommendation System using Document Embedding).ipynb'

# %%
from os.path import join


ROOT='/content/drive'
PROJ = "/gdrive/MyDrive/'Colab Notebooks'/deeplearning_NLP"
PROJ_PATH=join(ROOT,PROJ)

# %%
import os
import sys

sys.path.insert(0, PROJ_PATH)

# %%
# %cd /content/gdrive/MyDrive/'Colab Notebooks'/deeplearning_NLP
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/deeplearning_NLP

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/deeplearning_NLP

# %%
# initialize하고 github 레포와 연결
! git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Colab Notebooks/deeplearning_NLP/.git/

# %%
# !git config --global user.email "dbj2000@naver.com"
# !git config --global user.name "dbj2000"

# %%
# !ls
# Out:
#  data
#  git_init.ipynb
# '잠재 디리클레 할당(Latent Dirichlet Allocation, LDA).ipynb'
# '잠재 의미 분석(Latent Semantic Analysis, LSA).ipynb'
#  perfume
# '문서 벡터를 이용한 추천 시스템(Recommendation System using Document Embedding).ipynb'

# %%
# !git add .

# %%
# !git status #상태 확인하기
# Out:
# On branch main
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	new file:   .gitignore
# 	modified:   git_init.ipynb

# %%
# !git commit -m "directory change"
# Out:
# [main c1102ff] directory change
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 .gitignore
#  rewrite git_init.ipynb (62%)

# %%
# !git branch -M main

# %%
# !git remote add origin https://dbj2000:wlsgusdud131@github.com/dbj2000/deeplearning_NLP.git

# %%
# “fatal: remote origin already exists” 라는 에러메시지가 뜨면 기존 remote를 제거하고 다시 설정
# !git remote rm origin

# %%
# !git push -u origin main
# Out:
# Counting objects: 27, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (25/25), done.
# Writing objects: 100% (27/27), 10.29 MiB | 3.67 MiB/s, done.
# Total 27 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), done.
# To https://github.com/dbj2000/deeplearning_NLP.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
